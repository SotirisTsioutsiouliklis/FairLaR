# %%
# Load data.
# %matplotlib notebook
import pandas as pd

# %%
ln = pd.read_csv("out_lfprn_value_dif_weighted.txt", sep="\t", names=["node", "pagerank", "diff", "com", "inRedRatio", "outRedRatio", "excToRed",
                                                "excToBlue", "avrInNeiOutRedRatio", "bestInNeiPgrnkPos"], header =0)
lp= pd.read_csv("out_lfprp_value_dif_weighted.txt", sep="\t", names=["node", "pagerank", "diff", "com", "inRedRatio", "outRedRatio", "excToRed",
                                                "excToBlue", "avrInNeiOutRedRatio", "bestInNeiPgrnkPos"], header =0)
lu = pd.read_csv("out_lfpru_value_dif_weighted.txt", sep="\t", names=["node", "pagerank", "diff", "com", "inRedRatio", "outRedRatio", "excToRed",
                                                "excToBlue", "avrInNeiOutRedRatio", "bestInNeiPgrnkPos"], header =0)

# %%
ln.head()
# Out:
#     node  pagerank      diff  com  inRedRatio  outRedRatio  excToRed  \
# 0   6964  0.005350 -0.003963    1    0.995098          1.0       0.0
# 1  17321  0.004347 -0.003269    1    0.986667          1.0       0.0
# 2   6452  0.002205 -0.001436    0    0.019608          0.0       0.5
# 3  14907  0.001678 -0.001240    1    1.000000          1.0       0.0
# 4  15430  0.001589 -0.001055    1    0.991304          1.0       0.0
#
#    excToBlue  avrInNeiOutRedRatio  bestInNeiPgrnkPos
# 0        0.5             0.994018                  1
# 1        0.5             0.992401                  0
# 2        0.0             0.014129                 22
# 3        0.5             0.996230                  5
# 4        0.5             0.988767                  0

# %%
# keep only gain
ln= ln.query('diff > 0')
lp = lp.query('diff > 0')
lu = lu.query('diff > 0')
#ln.drop("node", axis=1, inplace=True)
#lp.drop("node", axis=1, inplace=True)
#lu.drop("node", axis=1, inplace=True)
#ln.drop("diff", axis=1, inplace=True)
#lp.drop("diff", axis=1, inplace=True)
#lu.drop("diff", axis=1, inplace=True)
#ln.drop("bestInNeiPgrnkPos", axis=1, inplace=True)
#lp.drop("bestInNeiPgrnkPos", axis=1, inplace=True)
#lu.drop("bestInNeiPgrnkPos", axis=1, inplace=True)

# %%
ln.head()
# Out:
#       node  pagerank      diff  com  inRedRatio  outRedRatio  excToRed  \
# 100  14018  0.000207  0.000259    1     0.59375         0.00       0.5
# 101  13598  0.000041  0.000186    1     0.50000         1.00       0.0
# 102   2336  0.000041  0.000184    1     0.00000         1.00       0.0
# 103   5198  0.000086  0.000162    1     0.60000         0.75       0.0
# 104   1348  0.000055  0.000133    0     1.00000         0.00       0.5
#
#      excToBlue  avrInNeiOutRedRatio  bestInNeiPgrnkPos
# 100   0.500000             0.497634                123
# 101   0.500000             0.130387                 33
# 102   0.500000             0.011905                 25
# 103   0.333333             0.157148                 31
# 104   0.000000             0.935484                 39

# %%
lp.plot.bar(x= 6, y='diff')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
lu.plot.bar(x= 6, y='diff')
# Out:
# <img src="data:image/png;base64,..." width="640">
