# %%
# Load data.
# %matplotlib notebook
import pandas as pd

# %%
ln = pd.read_csv("out_lfprn_value_dif_weighted.txt", sep="\t", names=["node", "diff", "com", "inRedRatio", "outRedRatio", "excToRed",
                                                "excToBlue", "avrInNeiOutRedRatio", "bestInNeiPgrnkPos"], header =0)
lp= pd.read_csv("out_lfprp_value_dif_weighted.txt", sep="\t", names=["node", "diff", "com", "inRedRatio", "outRedRatio", "excToRed",
                                                "excToBlue", "avrInNeiOutRedRatio", "bestInNeiPgrnkPos"], header =0)
lu = pd.read_csv("out_lfpru_value_dif_weighted.txt", sep="\t", names=["node", "diff", "com", "inRedRatio", "outRedRatio", "excToRed",
                                                "excToBlue", "avrInNeiOutRedRatio", "bestInNeiPgrnkPos"], header =0)

# %%
# keep only gain
ln= ln.query('diff > 0')
lp = lp.query('diff > 0')
lu = lu.query('diff > 0')

# %%
#plot scatters.
ln.drop("node", axis=1, inplace=True)
lp.drop("node", axis=1, inplace=True)
lu.drop("node", axis=1, inplace=True)

# %%
ln.drop("diff", axis=1, inplace=True)
lp.drop("diff", axis=1, inplace=True)
lu.drop("diff", axis=1, inplace=True)

# %%
ln.drop("bestInNeiPgrnkPos", axis=1, inplace=True)
lp.drop("bestInNeiPgrnkPos", axis=1, inplace=True)
lu.drop("bestInNeiPgrnkPos", axis=1, inplace=True)

# %%
lp.boxplot(rot=25, notch=True)
# Out:
# <img src="data:image/png;base64,..." width="934">

# %%
lp.head(20)
# Out:
#     com  inRedRatio  outRedRatio  excToRed  excToBlue  avrInNeiOutRedRatio
# 10    1    1.000000     0.000000  0.520458   0.000000             0.699076
# 11    1    1.000000     0.883721  0.000000   0.411060             0.859838
# 12    1    1.000000     0.500000  0.040917   0.000000             0.805648
# 13    1    1.000000     0.000000  0.520458   0.479542             0.721371
# 14    1    1.000000     0.666667  0.000000   0.219313             0.899287
# 15    1    1.000000     0.300000  0.314940   0.000000             0.781996
# 16    1    1.000000     0.066667  0.486205   0.000000             0.770966
# 17    1    1.000000     0.000000  0.520458   0.479542             0.793884
# 18    0    0.895522     0.000000  0.520458   0.000000             0.481766
# 19    0    0.741935     0.000000  0.520458   0.000000             0.323876

# %%
lu.boxplot(rot=25, notch=True)
# Out:
# <img src="data:image/png;base64,..." width="695">

# %%
lu.head(20)
# Out:
#     com  inRedRatio  outRedRatio  excToRed  excToBlue  avrInNeiOutRedRatio
# 10    1         1.0     0.666667  0.000000   0.219313             0.899287
# 11    1         1.0     0.668750  0.000000   0.221745             0.886237
# 12    1         1.0     0.878261  0.000000   0.407399             0.913500
# 13    1         1.0     0.864078  0.000000   0.397672             0.895626
# 14    1         1.0     0.580645  0.000000   0.103655             0.949198
# 15    1         1.0     1.000000  0.000000   0.479542             0.830859
# 16    1         1.0     0.833333  0.000000   0.375450             0.906916
# 17    1         1.0     0.950000  0.000000   0.452149             0.890409
# 18    1         1.0     0.800000  0.000000   0.349427             0.885999
# 19    1         1.0     0.341463  0.271807   0.000000             0.768824

# %%
ln.boxplot(rot=25, notch=True)
# Out:
# <img src="data:image/png;base64,..." width="718">
